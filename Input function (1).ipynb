# %%
Age=float(input("Enter Age"))
Gender=float(input("Enter Gender"))
Total_Bilirubin=float(input("Enter Total Bilirubin value"))
Direct_Bilirubin=float(input("Direct Bilirubin value"))
Alkaline_Phosphotase=float(input("Alkaline Phosphotase value"))
Alamine_Aminotransferase=float(input("Alamine Aminotransferase value"))
Aspartate_Aminotransferase=float(input("Aspartate Aminotransferase value"))
Total_Protiens=float(input("Total Protiens value"))
Albumin=float(input("Enter Albumin value"))
Albumin_and_Globulin_Ratio=float(input("Albumin and Globulin Ratio value"))
# Out:
# Enter Age 49
# Enter Gender 1
# Enter Total Bilirubin value 1
# Direct Bilirubin value 1
# Alkaline Phosphotase value 1
# Alamine Aminotransferase value 1
# Aspartate Aminotransferase value 1
# Total Protiens value 1
# Enter Albumin value 1
# Albumin and Globulin Ratio value 1

# %%
Age=float(input("Enter Age"))
# Out:
# Enter Age 41

# %%
Age
# Out:
# 41.0
